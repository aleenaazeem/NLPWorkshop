# %%
from sentence_transformers import SentenceTransformer
import pandas as pd
from scipy import stats

# %%
df_test = pd.read_csv("wordsim353crowd.csv")
df_test['Human (Mean)']/=df_test['Human (Mean)'].max()
first_col = df_test['Word 1']
second_col = df_test['Word 2']
gt_list = df_test['Human (Mean)']

# %%
model = SentenceTransformer('jfarray/Model_paraphrase-multilingual-mpnet-base-v2_100_Epochs')
encode1 = model.encode(first_col)
encode2 = model.encode(second_col)
predictions = model.similarity_pairwise(encode1, encode2)
spearmanr_score = stats.spearmanr(predictions, gt_list)
print(f'spearmanr_score: {spearmanr_score.statistic}')
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.79k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/821 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# spearmanr_score: 0.7900342420934038

# %%
predictions
# Out:
# tensor([0.4957, 0.3465, 0.7137, 0.2023, 0.6369, 0.2915, 0.4678, 0.1558, 0.2476,
#         0.2922, 0.4136, 0.5344, 0.3592, 0.5296, 0.4177, 0.1550, 0.4946, 0.5609,
#         0.3543, 0.4036, 0.5277, 0.4163, 0.5731, 0.4003, 0.3072, 0.6675, 0.4580,
#         0.2696, 0.7441, 0.5623, 0.3623, 0.8624, 0.5190, 0.9649, 0.3261, 0.4339,
#         0.4114, 0.4223, 0.5186, 0.6582, 0.3402, 0.3932, 0.2040, 0.4965, 0.2871,
#         0.3098, 0.8022, 0.5691, 0.3261, 0.5939, 0.5577, 0.3666, 0.2171, 0.6056,
#         0.3170, 0.2236, 0.2747, 0.4495, 0.2737, 0.4582, 0.3330, 0.5195, 0.3552,
#         0.3761, 0.7188, 0.6213, 0.2974, 0.2831, 0.5163, 0.3672, 0.4264, 0.4072,
#         0.2908, 0.4845, 0.3285, 0.3198, 0.1157, 0.4549, 0.2447, 0.1763, 0.3727,
#         0.3871, 0.3655, 0.2591, 0.3748, 0.3747, 0.3470, 0.3690, 0.4451, 0.1830,
#         0.5372, 0.3562, 0.5414, 0.2699, 0.5064, 0.5907, 0.2736, 0.2489, 0.4227,
#         0.2419, 0.3243, 0.5091, 0.2386, 0.3696, 0.1071, 0.7954, 0.4223, 0.6588,
#         0.2517, 0.2408, 0.3250, 0.5289, 0.4977, 0.5437, 0.3055, 0.2410, 0.4695,
#         0.3639, 0.2400, 0.4236, 0.6385, 0.2863, 0.3471, 0.4898, 0.6811, 0.3751,
#         0.3627, 0.2670, 0.5159, 0.4181, 0.7334, 0.4715, 0.1996, 0.3206, 0.3890,
#         0.2130, 0.3358, 0.2954, 0.7491, 0.2195, 0.2927, 0.4638, 0.4848, 0.4596,
#         0.3662, 0.3171, 0.3994, 0.4406, 0.3813, 0.3589, 0.7666, 0.6564, 0.2582,
